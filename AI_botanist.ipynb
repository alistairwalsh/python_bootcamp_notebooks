# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
# 5         setosa
# 6         setosa
# 7         setosa
# 8         setosa
# 9         setosa
# 10        setosa
# 11        setosa
# 12        setosa
# 13        setosa
# 14        setosa
# 15        setosa
# 16        setosa
# 17        setosa
# 18        setosa
# 19        setosa
# 20        setosa
# 21        setosa
# 22        setosa
# 23        setosa
# 24        setosa
# 25        setosa
# 26        setosa
# 27        setosa
# 28        setosa
# 29        setosa
#          ...
# 120    virginica
# 121    virginica
# 122    virginica
# 123    virginica
# 124    virginica
# 125    virginica
# 126    virginica
# 127    virginica
# 128    virginica
# 129    virginica
# 130    virginica
# 131    virginica
# 132    virginica
# 133    virginica
# 134    virginica
# 135    virginica
# 136    virginica
# 137    virginica
# 138    virginica
# 139    virginica
# 140    virginica
# ...

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.iloc[:,0:5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.iloc[0:3,0:2]
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2

# %%
df.loc[0:3,'sepal_length':'sepal_width']
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# %%
y = df[['species']]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.tail()
# Out:
#        species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
df['colour'] = colours

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species colour
# 0             5.1          3.5           1.4          0.2     setosa    red
# 1             4.9          3.0           1.4          0.2     setosa    red
# 2             4.7          3.2           1.3          0.2     setosa    red
# 3             4.6          3.1           1.5          0.2     setosa    red
# 4             5.0          3.6           1.4          0.2     setosa    red
# 5             5.4          3.9           1.7          0.4     setosa    red
# 6             4.6          3.4           1.4          0.3     setosa    red
# 7             5.0          3.4           1.5          0.2     setosa    red
# 8             4.4          2.9           1.4          0.2     setosa    red
# 9             4.9          3.1           1.5          0.1     setosa    red
# 10            5.4          3.7           1.5          0.2     setosa    red
# ...

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
my_dict = {'setosa':'red', 'versicolor':'green', 'virginica':'blue'}

# %%
type(my_dict)
# Out:
# dict

# %%
pd.DataFrame({'first':[1,2,3,4],'second':[10,20,30,40],'third':[100,200,300,400]})
# Out:
#    first  second  third
# 0      1      10    100
# 1      2      20    200
# 2      3      30    300
# 3      4      40    400

# %%
my_dict['setosa']
# Out:
# 'red'

# %%
df['species'].map({'setosa':'red', 'versicolor':'green', 'virginica':'blue'})
# Out:
# 0       red
# 1       red
# 2       red
# 3       red
# 4       red
# 5       red
# 6       red
# 7       red
# 8       red
# 9       red
# 10      red
# 11      red
# 12      red
# 13      red
# 14      red
# 15      red
# 16      red
# 17      red
# 18      red
# 19      red
# 20      red
# 21      red
# 22      red
# 23      red
# 24      red
# 25      red
# 26      red
# 27      red
# 28      red
# 29      red
#        ...
# 120    blue
# 121    blue
# 122    blue
# 123    blue
# 124    blue
# 125    blue
# 126    blue
# 127    blue
# 128    blue
# 129    blue
# 130    blue
# 131    blue
# 132    blue
# 133    blue
# 134    blue
# 135    blue
# 136    blue
# 137    blue
# 138    blue
# 139    blue
# 140    blue
# 141    blue
# 142    blue
# 143    blue
# 144    blue
# 145    blue
# 146    blue
# 147    blue
# 148    blue
# 149    blue
# Name: species, Length: 150, dtype: object

# %%
X.plot.scatter(x = 'petal_length',
               y = 'petal_width',
               c = df['species'].map({'setosa':'red', 'versicolor':'green', 'virginica':'blue'}))

# %%
sns.heatmap(X.corr(),annot=True)

# %%
sns.heatmap(X.cov(),annot=True)

# %%
y.head()
# Out:
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
for s in df['species']:
    print(s)
# Out:
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# ...

# %%
# 50 'red', 50 'blue', 50 'green'

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
colours = []

for item in df['species']:
    if item == 'setosa':
        #print('red')
        colours.append('red')
    elif item == 'versicolor':
        #print('green')
        colours.append('green')
    else:
        #print('blue')
        colours.append('blue')

len(colours)
# Out:
# 150

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# 5             5.4          3.9           1.7          0.4
# 6             4.6          3.4           1.4          0.3
# 7             5.0          3.4           1.5          0.2
# 8             4.4          2.9           1.4          0.2
# 9             4.9          3.1           1.5          0.1
# 10            5.4          3.7           1.5          0.2
# 11            4.8          3.4           1.6          0.2
# 12            4.8          3.0           1.4          0.1
# 13            4.3          3.0           1.1          0.1
# 14            5.8          4.0           1.2          0.2
# ...

# %%
y
# Out:
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# 5       setosa
# 6       setosa
# 7       setosa
# 8       setosa
# 9       setosa
# 10      setosa
# 11      setosa
# 12      setosa
# 13      setosa
# 14      setosa
# 15      setosa
# 16      setosa
# 17      setosa
# 18      setosa
# 19      setosa
# 20      setosa
# 21      setosa
# 22      setosa
# 23      setosa
# 24      setosa
# 25      setosa
# 26      setosa
# 27      setosa
# 28      setosa
# 29      setosa
# ..         ...
# 120  virginica
# 121  virginica
# 122  virginica
# 123  virginica
# 124  virginica
# 125  virginica
# 126  virginica
# 127  virginica
# 128  virginica
# 129  virginica
# 130  virginica
# 131  virginica
# 132  virginica
# 133  virginica
# 134  virginica
# 135  virginica
# 136  virginica
# 137  virginica
# 138  virginica
# 139  virginica
# 140  virginica
# 141  virginica
# 142  virginica
# 143  virginica
# 144  virginica
# 145  virginica
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
a, b = 10, 100

# %%
a
# Out:
# 10

# %%
b
# Out:
# 100

# %%
train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
# [     sepal_length  sepal_width  petal_length  petal_width
#  96            5.7          2.9           4.2          1.3
#  105           7.6          3.0           6.6          2.1
#  66            5.6          3.0           4.5          1.5
#  0             5.1          3.5           1.4          0.2
#  122           7.7          2.8           6.7          2.0
#  67            5.8          2.7           4.1          1.0
#  28            5.2          3.4           1.4          0.2
#  40            5.0          3.5           1.3          0.3
#  44            5.1          3.8           1.9          0.4
#  60            5.0          2.0           3.5          1.0
#  123           6.3          2.7           4.9          1.8
#  24            4.8          3.4           1.9          0.2
#  25            5.0          3.0           1.6          0.2
#  23            5.1          3.3           1.7          0.5
#  94            5.6          2.7           4.2          1.3
# ...

# %%
type(y['species'])
# Out:
# pandas.core.series.Series

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y['species'], test_size=0.33, random_state=42)

# %%
for group in [X_train, X_test, y_train, y_test]:
    print(group.shape)
# Out:
# (100, 4)
# (50, 4)
# (100,)
# (50,)

# %%
cls = KNeighborsClassifier()
cls.f
